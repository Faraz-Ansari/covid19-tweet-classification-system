# %% [markdown]
# ### 1. Importing all required modules
#
# Before importing, please make sure all modules are installed before running the project.

# %%
import pandas
import numpy
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, jaccard_score

import re  # library for regular expression operations
import string  # for string operations

import nltk
from nltk.corpus import stopwords  # module for stop words that come with NLTK
from nltk.stem import WordNetLemmatizer  # module for stemming
from nltk.tokenize import TweetTokenizer  # module for tokenizing strings
from nltk.sentiment import SentimentIntensityAnalyzer

import matplotlib.pyplot as plt

# %% [markdown]
# ### 2. Download all necessary nltk files

# %%
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Error loading stopwords: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
# [nltk_data] Error loading wordnet: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
# [nltk_data] Error loading omw-1.4: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
# [nltk_data] Error loading vader_lexicon: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
# False

# %% [markdown]
# ### 3. Importing the dataset

# %%
df = pandas.read_csv("covid_dataset.csv")

df.head(10)
# Out:
#    ID                                              Tweet  Sentiment
# 0   0  BanMediaHouse whose is responsible for spreadi...          1
# 1   1  Im waiting for someone to say to me that all t...          1
# 2   2  He is a liar. Proven day night. Time again. Li...          1
# 3   3  NEW: U.S. CoronaVirus death toll reaches 4,000...          0
# 4   4  Coronavirus impact Govt extends I-T deadlines ...          0
# 5   5  42,000 people might have died in China from Co...          0
# 6   6  This is how the govt of kenya is checking the ...          0
# 7   7  you are a complete wanker, and I hope you die ...          1
# 8   8  Just heard that my Oncle in France has the Cov...          1
# 9   9  That moment you realize your new medication ha...          0

# %% [markdown]
# #### Deleting unnecessary columns

# %%
try:
    df.drop(['ID'], axis=1, inplace=True)
except KeyError:
    pass

df.head(10)
# Out:
#                                                Tweet  Sentiment
# 0  BanMediaHouse whose is responsible for spreadi...          1
# 1  Im waiting for someone to say to me that all t...          1
# 2  He is a liar. Proven day night. Time again. Li...          1
# 3  NEW: U.S. CoronaVirus death toll reaches 4,000...          0
# 4  Coronavirus impact Govt extends I-T deadlines ...          0
# 5  42,000 people might have died in China from Co...          0
# 6  This is how the govt of kenya is checking the ...          0
# 7  you are a complete wanker, and I hope you die ...          1
# 8  Just heard that my Oncle in France has the Cov...          1
# 9  That moment you realize your new medication ha...          0

# %% [markdown]
# #### Assigning the variables

# %%
x = df['Tweet']
y = df['Sentiment']

# %% [markdown]
# #### Average length of tweet

# %%
tweet_length = 0
for tweet in x:
    tweet_length += len(tweet)

average_length = tweet_length / len(x)

print(f'Average length of tweet = {round(average_length, 2)} characters')
# Out:
# Average length of tweet = 97.61 characters

# %% [markdown]
# ### 4. Processing of Tweets i.e. removing symbols, stopwords etc from the tweet, tokenization of tweet and lemmatization the tweets.
#
# We are using lemmatization instead of stemming because stemming uses stem (base) of the word to analyse it.
# While lemmatization uses context of the word to analyse the text and reduce it.
# That is why lemmatization is more accurate in this case.

# %%
## param: string
## return : list of processed string ['first', 'second', 'third']  

def process_tweet(tweets):
    lemmatizer = WordNetLemmatizer()
    stopwords_english = stopwords.words('english')

    # remove stock market stickers like $GE
    tweets = re.sub(r'\$\w*', '', tweets)

    # remove old style retweet text "RT"
    tweets = re.sub(r'^RT[\s]+', '', tweets)

    # remove hyperlinks
    tweets = re.sub(r'https?:\/\/.*[\r\n]*', '', tweets)

    # remove hashtags, only removing the hash # sign from the word
    tweets = re.sub(r'#', '', tweets)

    # tokenize tweets
    tokenizer = TweetTokenizer(preserve_case=False, strip_handles=True,
                               reduce_len=True)
    tweet_tokens = tokenizer.tokenize(tweets)

    clean_tweets = []
    for word in tweet_tokens:
        # remove stopwords and remove punctuation
        if (word not in stopwords_english and word not in string.punctuation):  
            
            # lemmatizing the word
            lemmatized_word = lemmatizer.lemmatize(word) 
            
            clean_tweets.append(lemmatized_word)

    return clean_tweets

# %% [markdown]
# #### Calculating the length of tweet and polarity score of that tweet

# %%
# param : list of string (tweet)
# return : 2-D list of tweet length and polarity scores e.g. [[23, 0.12, 0.34, 0.45], ...]

def get_polarity_score(tweets):
    sentiment_analyzer = SentimentIntensityAnalyzer()
    sentiment_score = []
    for tweet in tweets:
        positivity_score = sentiment_analyzer.polarity_scores(tweet)['pos']
        negativity_score = sentiment_analyzer.polarity_scores(tweet)['neg']
        #neutrality_score = sentiment_analyzer.polarity_scores(tweet)['neu']
        #compound_score = sentiment_analyzer.polarity_scores(tweet)['compound']
        #sentiment_score.append([len(tweet), positivity_score, negativity_score, neutrality_score, compound_score])
        sentiment_score.append([len(tweet), positivity_score, negativity_score])
    return sentiment_score

# %% [markdown]
# #### Iterating over the each tweet and then processing it and finally storing processed tweets in a list

# %%
# an empty list to store all processed tweets
processed_x = []
for tweet in x:
    clean_tweet = " ".join(process_tweet(tweet))
    processed_x.append(clean_tweet)
    
processed_x
# Out:
# ['banmediahouse whose responsible spreading fake communal story pandemic corona situation',
#  'im waiting someone say corona thing april fool joke',
#  'liar proven day night time lie truth covid 19',
#  'new u coronavirus death toll reach 4,000 nearly 900 new death reported today bno news covid 19 coronavirusoutbreak',
#  'coronavirus impact govt extends i-t deadline related section 80c 80d',
#  '42,000 people might died china covid 19 china underreporting according source',
#  'govt kenya checking temperature covid 19 saying still low mtashangaa sana',
#  'complete wanker hope die coronavirus fucking dickhead',
#  'heard oncle france covid 19 coma critical condition guy please aint joke safe',
#  'moment realize new medication side effect identical corona virus symptom know',
#  'three team fighting covid 19 day night 1 doctor nurse policeman 2 khan pr team 3 cell',
#  "six new coronavirus case reported karnataka taking state's tally 181 coronavirusoutbreak cautionyespanicno",
#  'lot chatter 16000 staff nightingale pop hospital coming covid 19',
#  'anyone good roundup country billionaire done respond coronavirus',
#  'coronavirus trump wed 1 apr 2020 00:00 00 cdt',
#  "what's procedure corona testing guy whole village need get tested p ..",
#  "wonder what's gonna come next first kobe corona ... what's next",
#  'problem poverty covered cover religion issue changed relief corona well',
#  'pushing free therapy health care worker covid 19 arc coming 2 end',
#  'emergency warning sign covid 19 new confusion inability arouse thatcouldmeananything bluish lip face thatsjustscary',
#  'corona like strange unreal horror movie everybody stay strong stay home take care much love',
#  'western country busy fighting covid _19 result terrorisme stoped world wide',
#  'im conspiracy theorist ... china set bioweapom coronavirus profiting',
#  'white butterfly clearly gave u clear signal something bad going happen ... corona virus',
#  'never heard seen better thing corona curfew enforcement',
#  'know who also risk corona virus people live apartment building',
#  'coronavirusupdate 38 coronavirus death india 1,637 positive case coronavirusoutbreak',
#  'mr amir khan also come speak fellow muslim obey medical necessity fight corona',
#  'chriscuomo weeping u coronavirus pray firstresponders quarantinelife family faith',
#  'pti_news covid 19 toll maharashtra 12 death two coronavirus positive patient health official',
#  'blame coronavirus wal-mart longer open 24/7 life good implemented new hour',
#  'n ofcourse there hyperstick right ebay 75 shipped covid 19 fucking swag right',
#  'end covid 19 crisis im determined able speak coherent romanian im moving german friend',
#  'satellite image show decline air pollution italy amid coronavirus lockdown',
#  "coronavirus talking one that's around 1,000 year novel covid 19",
#  'someone threw corona virus party 40 people 550sft apt whole as dj ..',
#  'true human right say alot regarding disposal deadbody lka covid 19',
#  'im working new blog covid 19 changing collegiate learning here at-home setup',
#  'coronavirus good lesson reminder american people need new government reliable source information',
#  'blue check fakenews cnn talking head angry okeefe actual on-the-ground journalism covid 19',
#  'getting say corona break im good time im ready miss bailey',
#  'anyone tell corona fuck ... proceed cause motha fucka bore mind',
#  'real though fsociety mrrobot wipe everyones debt covid 19 booochet much appreciated yall',
#  'jaejoong baby there trend jp spread lie corona april first n includes lying',
#  'eugenics george soros bill gate partner china coronavirus drug',
#  'man say like listen please follow advice coronavirus covid 19',
#  'corona virus ruined senior year ok tho im making best',
#  'another year earth gone get stay inside bday coronavirus hoe :-)',
#  'white house predicts 100 000 - 2400 0 die usa corona virus',
#  '1/16 corona virus god natural evil god jesus hand washing',
#  "forsee real race war south africa coronavirus people's eye mind reconcietised",
#  'breaking foxnews alert coronavirus death toll u reach 4,000',
#  'need stark reminder covid 19 challenge need wake better 1/4',
#  'hero time murad ali shah please check increase corona virus case left punjab behind best performance',
#  'news update hindustan time 9 coronavirus death rate lower estimate study latest news hour',
#  '8,50 000 corona case :( number keep increasing covid 19',
#  'meanwhile jeffrey dahmer steroid aka sh covid 19',
#  'long diagnostics coronavirus vital opportunity sector cease illuminatti',
#  'please stop leaving house taking coronavirus stuff joke keep going friend stuff seriously',
#  'dang officially know someone tested positive corona virus oml',
#  'going biblical grade end-of-times shit rn covid 19 idahoearthquake locustinvasion',
#  '31 march 2020 confirmed 75,122 death 4,525 coronavirus',
#  "ur director total ignorant missled world china's corona virus killing 000 worldwide fired incompetent",
#  'chris time get sick come man kill corona come back screen hurry best',
#  "cavalier politician people's property unfettered competition credit saving life coronavirus",
#  'covid 19 lockdown situation like existential crisis hanging head .. pmkcallscurfewextension',
#  'one thing sure corona virus really good environment',
#  'supposed go europe fucking june fucking corona took big shit trip oh god',
#  'welcome april hope get better soon covid 19 soon disappear earth',
#  'bhilwara-has-become-a-global-role-model-by-breaking-the-corona-chain-with-efforts-made-by-the-state-government',
#  'asuma white house project 120,000- 240,000 coronavirus death u ...',
#  'busy busy busy many thing pandemic create work doubt covid 19 digdigdig fundsfundsfuns',
#  'covid 19 common remorse theyll take last breath last dime',
#  'world think making joke april fool coronavirus ok',
#  'e-commerce delivery service working delhi food item covid 19 curfewinindia delhi',
#  'thank god coronavirus hasnt stopped new k-pop',
#  'u using covid 19 excuse give schedule got 7 group',
#  'free time bc corona still cant seem figure respond ppl bumble need help',
#  'death kenya coronavirus 1 2 curfew protect spread covid 19',
#  'corona killed 1 police already killed 2 .. call prevention',
#  'sigh 1 224 within one month long month march 2020 coronavirushawaii',
#  'remember also touch face place like mouth nose qnd eye since corona virus enters body via part jumiaheroes',
#  'coronavirus cant kill god amazing sunset every night',
#  'never made child ... much wrong world covid 19 climatechange climatejustice cometaatlas',
#  'kill ... get tested covid 19 im gonna asked put sleep ... im serious',
#  'depressing coronavirus news uplifting tweet welcome back stabler dundun',
#  'mile 12 market remain open farmer still supply fresh produce covid 19 mile 12market',
#  'judiciary biased impressed anti hindu anti national medium also jail safe prevention corona coronariskforprisoners',
#  'ministry health labor welfare sent survey line see might coronavirus',
#  '106 new confirmed case austria totaling 10,298 place already 860,035 worldwide coronavirus covid 19 austria',
#  '2020 suck good news anything good happening anything coronavirus codvid 19 quarantinelife',
#  'speaking daddy probably meeting may stupid corona :(',
#  'corona virus helping environment air earth getting cleaner',
#  'coronavirus must fought everyone collectively deviding u religious line muslim islam',
#  'today okay feel good corona virus job searching really hard mental health',
#  'colleague talk human rights-based response covid 19',
#  'biggest coronavirus fails right usa uk government',
#  'florida texas among others need start act coronavirus coronaupdate',
#  'called islamic corona jehad tablike jamat making full india lockdown relizius terurrist',
#  'dis corona tin na scam oo na competition country dey country highest corona case world bank go give dem money',
#  'cnn cuomo--economic expert alexis glick talk financial--the difficulty american experiencing b c coronavirus',
#  'sitting back letting corona case death rack',
#  "7:39 p feel like woke 2 hour ago :') hate ... coronavirus go away :(",
#  'every state county city neighborhood coming yet many still wait act covid 19us',
#  'please careful safe especially coronavirus going around',
#  'use twitter nothing pl focus corona virus help needy citizen peace peace peace',
#  'talked doctor friend apparently number one way get coronavirus tainted toilette paper thank karma',
#  'sarcastic trudeau gov disaster liar trudeau gov allowed coronavirus spread canada',
#  'corona patient recovered private hospital employer footed bill r 12 lakh',
#  'march come passed covid 19 seems forever last wake april end covid 19 covid greenday',
#  'miss singing heart church every sunday :( corona go away',
#  'come attention ausstudy qualify coronavirus supplement fortnight student bent',
#  'covid 19 please end soon possible wanna meet bebe family',
#  'hell way kick newdecade factsmatter covid 19 trumpisavirus trumpliespeopledie allinthistogether',
#  'happy april fool yall please stay safe sensitive situation aka dont make covid 19 joke',
#  'anyone know russia syria north korea corona virus hearing anything country',
#  '240,000 die coronavirus lucky think',
#  'hear word corona one mo time im beating somebody as',
#  'giliran corona harga hotel murce 2 pen staycations aing',
#  'spoke doctor another confirmation cure coronavirus 100 effective',
#  'covid 19pakistan ulema asked abide government coronavirus-related instruction lockdownpakisan',
#  'apparently 710,000 people die corona bar thats crazy stuff right',
#  'people dumb acting stupid corona cant easily kill young adult huh',
#  'twang getting fucking bad need cure corona immediately stop hanging family im begging',
#  'corona virus pandemic going leave people bankrupt dead',
#  'keep mask close keep sanitizers closer mario puzo covid 19',
#  'wish make cash donation help stop speed corona virus may please',
#  'much longer til life go back normal covid 19 coronavirus',
#  'really dont think appropriate joke corona time like',
#  'china made whole world aprilfools false report covid 19 spread december january',
#  'cc moron support peddling drug untested fight covid 19',
#  'supposed know sick .. complex thing come .. covid 19',
#  'every nurse medical professional frontlines covid 19 crisis getting hazard pay crazy many',
#  'groundhog get coronavirus worried gu second famous ground hog pennsylvania',
#  'next year jerusalem homemade gelfite fish world coronavirus vaccine',
#  'well officially april 1st one come said whole corona thing joke',
#  'breaking tablighi jamat donates 2100 coronavirus patient pm relief fund',
#  'april fool day 2 work colleague died coronavirus aint joke rip',
#  'mentioned infectious virus 1/3 nursing home resident died covid 19',
#  'rip 200,000 beautiful soul already taken coronavirus p l e e stayhome socialdistance sixfeet',
#  'checkout page good content raw footage twitter page coronavirus covid 19',
#  'corona anxiety real ... 1 month jobless house coronavirus chicago',
#  'feku must enjoying others work get amass crore name covid 19',
#  'saw segment trump administration purchasing monkey test covid 19 treatment source',
#  'happy new month may dis new month drive corona away staysave stay',
#  'swear single joke tomorrow corona virus sport back quarantine',
#  'everyone telling people got coronavirus say april fool hope get hit fucking car',
#  'coronavirus u doctor nurse overseas desperate come home border close',
#  'march saw u coronavirus case go 42 182,000',
#  'package coming ny basically im gonna get corona',
#  'year ... kobe dy helicopter crash isnt even biggest news headline los angeles q1 covid 19',
#  'hope people start acting sense urgency restraint covid 19',
#  'oopsies lakeland decided reopen park coronavirus isnt already fucking u completely (:',
#  'human four-year-old female malayan tiger bronx zoo new york tested positive coronavirus',
#  'korea report 101 case new coronavirus total 9,887 ea first squawk roboinfo 0.120 robotex group',
#  'alright corona shit got serious ima stay as home sunday funday',
#  'dear covid 19 enough messing around .. scared better ruin ramadan fast tarawihs',
#  'dey tell say omo guy duru die dey day corona kill ... bn chill last week .. stay',
#  'hey really trumped coronavirus response trumped everything smell like trump',
#  'elite afraid corona virus brought citizen afraid hunger deliberately created elite',
#  "sloth's wednesday slow-poll what's greatest fear corona aftermath comment others ):",
#  'worry coronavirus please',
#  'turn real death panel bunch degenerate coronavirus trumpvirus',
#  'corona virus medium govt conspiracy porn next 9/11 truther movement plausibility',
#  'shoutout making coronavirus testing easy eli lilly complicated',
#  'world want know thrown florida bus goal covid 19',
#  'dont understand people saying coronavirus flu youre one people please explain',
#  'leave republican find new way kill american within pandemic coronavirus gopdepravity',
#  "covid 19 shall see end shall see end covid 19 psalm 118:17 happy new month y'all",
#  'pray p200 b really reach poor covid 19 pray prayforphilippines',
#  'jeff grosso passed away complication coronavirus today',
#  'tested positive fucking sick corona break getting rowdy w boy',
#  'hasnt got clue jesus christ ally contradicting information nut covid 19 gmb',
#  'april finally guy ... happy new month everyone ... stay corona-free protect loved one ... aprilfoolsday',
#  'first death corona u P: mistake family threatened hundred',
#  'democrat politicizing coronavirus . . . new hoax donald trump february 28 2020',
#  'one who worried yellowstone erupting 6.5 earthquake idaho instead corona virus',
#  '6.5 quake idaho 400 mile yellowstone caldera supervolcano covid 19',
#  'coronavirus-more-then 4000 cases-in-pakistan-doctors-strike-end-now',
#  'could italy highest coronavirus death outside china',
#  'need bring corona fest back sanity',
#  'stay home covid 19 update country channel island total case 335 total death 7 total recovered 34 total active case 294',
#  'think covid 19 back january want antibody test herdimmunity antibodytest coronavirus covid 19 covid 19',
#  'randal l stephenson ceo doesnt want american hear directly coronavirus task force',
#  'johnsonjohnson said made progress vaccine covid _19 product could ready early 2021 wsj',
#  "gonna great month i'm speaking existence regardless corona disaster",
#  'april wish corona disappears world soon get better',
#  'yay cnn way go airing informative section covid 19 daily briefing thank',
#  'corona shit need spend time nigga dude family',
#  'corona case reached 58 p stayhomestaysafe covid 19india',
#  'toronto joker stupid imran khan read canadian medical report 90 corona virus case 30 40',
#  'man talking corona spread leasure time ... countryside cutting service putting omg',
#  'serious question anyone personally know someone who died coronavirus cuz sure hell dont',
#  'wait ... said kim jaejoong got positive corona virus april moop omg',
#  'shout truly respect way youre leading ny crisis covid 19',
#  'prayer condolence go people lost loved one due coronavirus',
#  'trump warns american tough two week ahead coronavirus fight u rtgnews',
#  'maybe biggest blessing coronavirus making u understand take granted',
#  'dr anbumani say lockdown way combat coronavirus outbreak pmkcallscurfewextension',
#  'corona virus got stuck house kid im thinking ... maybe kid aint bad',
#  'uk todaycases 3009 3009 0 todaydeaths 381 381 0 covid 19aus covid 19',
#  'corona control encourage cottage industry restrict people home',
#  'starting tomorrow get full month 4/20 smoking buddy cause corona tf kinda shit man',
#  'coronavirus refuse stay indoors ive done part summer holiday im ready erryday',
#  'watched 1 news channel corona mama update shit shit getting annoying',
#  'diet consists nacho havent showered 2 day coronavirus',
#  'trump didnt act covid 19 fast enough pause election get another year',
#  'feelin lot like coronavirus patient lately way im sick hell',
#  'juuls introduced weaken immune system teenager making susceptible planned covid 19 outbreak',
#  'corona token investbox daily percent c amount corona buy order 10 max percent 10 day',
#  'come sam winnall tested covid 19 wasnt showing symptom wish speedy recovery',
#  'always love customer learned protect refused protect u covid 19 front line customer service worker',
#  'tomorrow april fool day corona virus prank move',
#  "ap total corona case :-8 7 12 hour's lo 43 case feeling gajagaja covid 19",
#  'fuck im job bc corona mean there going physical album op',
#  'afraid terrified since january 20 2017 worstpresidentever norespectfordonaldtrump coronavirus',
#  'j release date pushed back ... thnx corona',
#  'binational security state implemented operation blackout use coronavirus',
#  'sure corona virus dab pen making throat itch',
#  'sir hope stop spreading killing corona virus need help dr kumaril',
#  'bei pls stop rting corona virus test tl knee begging',
#  'mcconnell say trump impeachment trial diverted attention government coronavirus entered u eat penguin shit',
#  'everyone get corona virus big april fool joke right dont see tomorrow pls',
#  'coronavirusinsa gauteng recorded first covid 19 death mortality rate south africa edging 0.37',
#  'eric clapton bonnie raitt dead 74 mr eric clapton bonnie corona virus maybe sure guardian angel cry',
#  'actually worrisome please take care ahmedabad coronaupdatesinindia',
#  'arsehole running cycling prom salthill absolute gobshites coronavirus',
#  'shame godi medium ... dangerous corona virus',
#  'u break one-day record covid 19 death reporting 865 fatality john hopkins university .. usa .. coronavirus ..',
#  '1 new confirmed case hong kong totaling 715 place already 858,127 worldwide coronavirus covid 19 hongkong',
#  "y'all really nerve say black ppl get coronavirus smfh",
#  'great commentary lot detail understand civic 19 covid 19 coronakodhona',
#  'sharing corona post think worth read stay home pray people',
#  'anyone else think many time day probably encounter pas actual corona virus know',
#  'may god save u stupid people spreading corona indiatrustspmmodi indiafightscoronavirus indiafightscorona',
#  'read book bed blog post tomorrow early depends kid really comparing civic covid 19 response',
#  'healthcare professional die government job handling covid 19 situation ... sad',
#  'request people india stay home fight corona virus',
#  'corona virus earthquake ... world gonna end like might well text ex',
#  'toxic relationship coronavirus letting u leave house',
#  'expose corrupt system leaf 99 population 3rd world condition covid 19',
#  'yo someone like kill corona dude see girlfriend already',
#  'wish covid 19 april fool day prank itd really happy april fool day',
#  'better see one fake piece corona news app wake',
#  'healthcare worker went strike far dangerous go work concentration people coronavirus',
#  'yall forgot nipsey like yall forgot dre yeah got time today coronavirus',
#  'want period boyfie fcking corona annoyingly send da hell',
#  'dont go outside let face one afford cost treatment coronavirus',
#  'could wake morning n coronavirus april fool joke :(',
#  'bf listing food place hit corona epidemic wewanttoeatout',
#  'coronavirus trump warns u headed painful two week',
#  'excited present legal tip combat covid 19 imapcts webinar hosted',
#  "i'll say good work leadership medium membersofthepresswtf covid 19 voteblue 2020",
#  'think ff7r shipping early japan coronavirus really hit u yet life pretty much continued usual',
#  'personally id rather die coronavirus willingly give freedom',
#  'interesting piece greece handling covid 19 crisis hope stay vigilant though',
#  'france ready shut border britain toughened coronavirus measure',
#  'corona shit really got type fucked thought joke ... hell',
#  '152 doctor 63 nurse nagpositive sa covid 19',
#  'inspired horrible leadership corona spread tried hero quit',
#  'fam fr cry alll day yesterday get piped today n feel unstoppable depression finna cure corona virus real quick',
#  'anti-vaxxers feel development coronavirus vaccine',
#  '3 positive case total number positive case jk today 14 139 total 139 covid 19',
#  'breaking u death coronavirus passed 4,000 according john hopkins tracker',
#  'scary nyt say world could remain kind indefinite lockdown vaccine treatment covid 19 found',
#  'wish fuckin wine home corona wasnt taking money could buy',
#  'cant wait whole coronavirus shit fucking end man got grandma shes gone ive enough',
#  'delhi doctor working delhi government hospital tested positive covid 19 coronavirusupdates india',
#  'jesus jenrick next layer cannon fodder put forward say improve coming week ... covid 19',
#  'mad moved right corona mess started cant even shop want',
#  'april fool day please dont say corona virus joke corona virus isnt funny',
#  'close boarder give u food give u money covid 19 enter delta state e red u',
#  'hope alot included jr tested steve bannon stephen miller coronavirus',
#  'im tired corona conspiracy theory stay home fucken survive please',
#  'one postive case ludhiana total number postive case punjab 42 coronavirus coronaupdatespunjab',
#  'im ignoring outright psychopathy anything corona coming wh right',
#  'ever gonna find kid spring break video caught coronavirus',
#  'seriously hope bezos child die horribly painful coronavirus death',
#  'increasing number coronavirus outbreak usa european english speaking country fake covid 19 liar',
#  'corona virus detected illegal citizen nrc ... thanks markaz circus',
#  '2020033 1 np coronavirus update globally one five people covid 19 american',
#  'there korean idol joking corona f cking okay',
#  'latest madison 365 wait election result spike coronavirus infection',
#  'dear corona please go away see may 2nd :( please thank',
#  'real please careful protect joke make fun friend die today coronavirus',
#  'u feel slightest bit cold ur wondering u corona :/',
#  'stay home covid 19 update country colombia total case 906 total death 16 total recovered 31 total active case 859',
#  'covid 19 psa however seriously youre taking covid 19 right take thread even seriously',
#  'fear grow coronavirus pandemic gaza amid israeli siege via savegazafromcorona siegeisepidemic',
#  'also supermarket shopping mall ... sad covid 19',
#  "april fool's day many youtubers pull coronavirus prank loved one today",
#  "must many tribulation enter kingdom god act 14:22 surprise god's people covid 19 wednesdaywisdom jesussaves",
#  'saw visuals test people see corona suddenly im trouble breathing god',
#  '9ja artist buying iced chain wristwatch worth million quiet covid 19 season ..',
#  'hope someone able pinpoint amazon coronavirus spread sue brake as greedy mofo smh',
#  'breaking news mlb suspending whole 2020 season due coronavirus',
#  'nimble comparison covid _19 influenza blockhead thx m victoria sharing',
#  'somebody help understand ... predicting second wave corona virus ... havent controlled first one',
#  'gross negligence contain let die care tablighijamaat coronajihaad',
#  'live town 5,000 people first case covid 19',
#  'premier john horgan announces extending state emergency b c covid 19 covid 19canada covid 19bc coronavirus',
#  'trump sobers admits next 2 week going painful coronavirus',
#  'done corona must re-visit tunapanga kenya minus bbi nonsense',
#  'cousin getting tested corona today guy pls pray',
#  'great job trump want 1 track highest covid number coronavirus',
#  'aspen really sent email saying dont forget rent due tomorrow well lost job bc corona say april fool rn',
#  'sister really said went vacation vacation good came back corona virus 4 ...',
#  'im throwing big as cookout corona shid way',
#  'know coronavirus shit suck rn honestly stuck inside whole month 4/20 doesnt sound awful',
#  'breaking 14 tested positive corona virus today jk .. total positive case stand 139',
#  'china admit whole corona virus thing came wuhan laboratory',
#  'gonna rant deleted whole thread corona shit im',
#  'least 811 new coronavirus death reported u tuesday according count cnn health',
#  'hey doc get covid 19 previously different type corona virus past thanks',
#  'wuhan chinese virus spread spread shanghai chinese area yes chinese corona weapon',
#  "sister's coworker tested postive corona work together .. fuck",
#  'gov.justice state official hold daily press briefing covid 19 1 pm coronavirus covid 19 wv',
#  'praying today find whole thing coronavirus april fool',
#  'im going need good coronavirus news reply tweet positive right covid 19 coronavirus covid 19',
#  'breaking foxnews alert watch live trump coronavirus task force explain updated guideline wh briefing',
#  'like 911 forever changed u covid 19 understand much control ...',
#  '200,000 people u died coronavirus last time checked getting ahead ...',
#  'come weve case corona dont see one person sanitizing shit',
#  'thank much uae indeed answered prayer coronavirus covid _19',
#  'mentor fighting coronavirus detroit hospital dont think ive ever prouder',
#  'yall need go therapy cant cause coronavirus shit wish could access online cant',
#  'heard fire bronx lebanon hospital someone confirm coronavirus newyorkcity',
#  'perhaps president missed mark bit given know say coronavirus wipeout 100-200 k american',
#  'losangeles shot 3,000 coronavirus case le week people refuse stay home',
#  '2 family member passed away covid 19 still see mad people hanging outside fuck yall honestly',
#  'see theyre still spreading coronavirus socialdistancing nigeria covid covid 19 health',
#  'oh god john mccain died die corona',
#  'crazy patient today may covid 19 mask glove whole time tho ...',
#  'wanna go back home miss bay fuckin coronavirus excited',
#  'anyone say theyre pregnant coronavirus april fool joke tomorrow fuckhead',
#  'honestly want corona thing go see harry style',
#  'big well known corona virus keep distance ..',
#  "say got coronavirus april fool joke i'm i'm reporting",
#  'theeylon contributed giveth coz giving covid 19 cause grant 523 giveth 20 decentralizing-nonprofits-with-covid 19 co',
#  'shelter-in-place baby boom gonna real tho covid 19 stayathome shelterinplace',
#  'egypt extends nationwide night-time curfew 15 day april 23 counter coronavirus spread alarabiya newsguru',
#  'lautoka lockdown extended till 5am 6th april covid 19',
#  "good job steven let's keep taking care covid 19",
#  'give fuck georgia 8th highest number death coronavirus crisis',
#  'greatest fear much getting corona giving someone',
#  'coronainmaharashtra also inform people covid air-borne virus important',
#  'alright april fool corona go away please',
#  'please may corona april fool prank tomorrow',
#  'know kid gonna asking question corona go back nooo idea tell yikes',
#  'abeg come say coronavirus april fool joke bc tired',
#  'please let know housing loan moratorium passed bank account covid 19 guided rbi',
#  'tune tomorrow 7:15 hear helping philadelphia hospital fight coronavirus',
#  'corona hilang x1 unit comeback not_sosmall_oneits',
#  'watching anchor despite positive covid 19 reason comforting speaks character',
#  'sick w cold coronavirus pandemic dangerous time',
#  'corona fucked life like wasnt already fucked enough',
#  'think corona change modern dating culture quarantine chill netflix chill potensh public health threat imo',
#  'swear bayfront music fest szn get canceled miss corona .. im throwing hand',
#  'rationalizing death comparing number disease probably absurd tweet ive seen twitter covid 19',
#  'corona case increased due central goverment lockdown rule passed maintains rule',
#  'trump apparently set goal 100,000 240,000 death due coronavirus presidency 78,000 vote',
#  'refused refund flight canceled due covid 19 thief give people money back',
#  'live 1 hour youtube facebooklive twitch covid _19 covidiot socialdistancing tigerking loveisblind',
#  'trump lied covid 19 claimed hoax result thousand people going die',
#  'american coronavirus death could thousand time allied death d-day',
#  'cant believe trans people get stop invisible one day year happened corona virus unfair',
#  'cool funny see headline april 1st claiming vaccine coronavirus found',
#  'let u pray person found positive red zone corona stay home stay safe',
#  'sensitive moment joke coronavirus bc everyone mourning shimura ken good luck booking stage u speak',
#  'talk importance existing home set ups minimize radiologist exposure covid 19',
#  'municipality covid 19 free thanks god wish whole world heal',
#  'employee love truck stop madera tested positive covid 19',
#  'mg physio business usual controlling risk infection',
#  'im sick tired coronavirus cant school home',
#  'surprised black people main one dying covid 19 healthcare isnt fair u',
#  'india affected two virus first one corona second shameful scary',
#  'understand maturity go house save life covid _19 real stayhomeknowgh',
#  'institute life science bhubaneswar conduct covid 19 test get nod',
#  'cant wait whole coronavirus thing take yings become true cheektowagan',
#  'please stop coronavirus false information probably put people risk',
#  'making joke gau mutra secular enterprise talking jamaats mischief communalising corona shoot messenger',
#  'frustration overheard 2 guy talking corona virus angrier one said disla corona virus eh wanpla kkk virus stret eh',
#  'soo gonna say april fool coronavirus bein thing',
#  'please coronavirus april fool joke prank thanks god bless',
#  'coronavirus unveiled easy simple islamic arewa marriage noise wahala basic nikah small walimah',
#  "whole coronavirus situation destroying everyone's peace mind end day can't let crush spirit",
#  'hope mr nsa quarantined .. went hotspot corona .. serious ..',
#  'stay home stay safe try best follow precautionary measure covid 19',
#  'three team fighting covid 19 day night 1 doctor nurse health official 2 modis pr team 3 cell',
#  'hey fyi 45 ... canada got told well month covid 19 measure',
#  '30 unemployment expected summer .. thats roughly 40 million unemployed american coronavirus crisis',
#  'thanks brilliant zoom covid 19 emergency payment tax everything x',
#  'shocked negative medium control enforced u hospital covid 19',
#  'today first day found anybody know corona 7 3 died 4 ventilator please safe yall',
#  'april fool today year fool bc thought year gonna lit coronavirus year sigh',
#  'proud work done visionary dedicated educator education time covid 19',
#  'mom call least 3 people everyday saying thing coronavirus like girl okaaay im tired hearing',
#  'anyone know long took democrat cnn politicise corona virus exact minute second minute',
#  'south korea report 101 new coronavirus case 24 hour bringing total 9887 bbg',
#  'u coronavirus underwood coverage colin could usa case unwitting central use cruise ufc cheat',
#  'coronavirusoutbreak 42,000 death due covid 19 worldwide 8.5 lakh people infected coronavirustruth',
#  'young kiddos highly recommend watching kidstogether town hall together coronavirus',
#  'noticing lot people getting peloton posting social medium stock covid 19 covid 19',
#  'im really indy til may ... coronavirus dumb bitch omfg',
#  "anyone coronavirus april's fool prank they're bad person",
#  'since cant actually hang cause corona face timing instead like hanging <3',
#  'pakistan report 93 new case bringing total confirmed case 2,031 26 total death coronavirus covid 19 coronavirusoutbreak',
#  'hospital morgue central park moment history .. rip every 1 lost stay tf home coronavirus itsreal',
#  'know soon corona shit wit lol',
#  '9 new recovery new zealand totaling 83 place already 178,099 worldwide coronavirus covid 19 newzealand',
#  'coronavirus forced restaurant across u either close limit service industry bounce back yahoo news',
#  'oh ya cousin husband live nyc got coronavirus thats today exciting news',
#  'first day work middle corona outbreak bismillah ..',
#  '4 new death hungary total death hungary 20 7 new death china total death china 3312 covid _19 covid 2019',
#  'zero rlly got pushed back cu coronavirus hate',
#  'life going coronavirus gone ... expensive world limited income large scale unemployment',
#  'dnt go tg lo 97 ap lo 87 corona positive case covid 19 stayhomestaysafe',
#  'chance youd jump podcast talk investing post corona chicago founder would love',
#  'stuck boat middle ocean hurricane bearing covid _19',
#  'agree question absolutely need asked answered coronavirus origin ...',
#  "please stop calling coronavirus hoax they're laughing u especially stay home muppets",
#  'covid 19 joke prank insensitive af people actually dying virus',
#  'create credit shell flight cancelled airline due covid 19 outbreak',
#  'breaking oman pardon almost 600 prisoner including 336 foreigner amid coronavirus fear good news',
#  'corona virus made forget wish happy new month happy new month guy let stay safe alive',
#  'wow first time sat finish 2 back back thanks covid 19 stay safe',
#  'idea accepting head shave challenge nurse worked corona covid 19 ...',
#  'im finally twitter hope everyone hanging coronavirus situation working hard resolve problem',
#  'im relieved uni providing student fund due covid 19',
#  'gaddar r every profession bwood cricketer 2020 corona brought every criminal open',
#  "yeh sure died coronavirus ... that's much coincidence",
#  'seeing post frontliners passing away covid 19 babawi kami sa 2022 u',
#  'god wash away corona virus rain ... jah bless ..',
#  'im telling yall thesis corona phase dream craaayy',
#  'breaking foxnews alert coronavirus death toll u reach 4,000',
#  '2 new recovery cambodia totaling 25 place already 178,144 worldwide coronavirus covid 19 cambodia',
#  'past midnight week night yep unemployed ... fuck coronavirus',
#  'stg corona shit wasnt happening nobody would hearing seeing sign',
#  'jae fckin joong got corona said trump himmm',
#  'u coronavirus death set one-day record 865 according john hopkins university afp news agency',
#  'ok trick question worse coronavirus cancer disrespect intended',
#  'bill melinda gate spend billion setting coronavirus vaccine factory good news',
#  'better see anyone making coronavirus april fool joke',
#  'corona released china damage american economy ... declaration war ...',
#  'could public really bring fox legal bloodbath covid 19usa',
#  'nigeria discharged 44 people maleria corona_virus corona virus yet nigeria ..',
#  'corona depression definitely hit harder seasonal god damn',
#  'breaking white house project 100,000 240,000 death u coronavirus',
#  'judiciary biased impressed anti hindu anti national medium also jail safe prevention corona coronariskforprisoners',
#  'sir please contribute amount combat corona virus country gave much',
#  'alhamdulilah april baby month month money heist coming month corona end allah mercy',
#  'imagine waking today realized covid 19 stuff april fool idea relief would coronavirus',
#  "gov't plan helping ugandan stranded abroad now-mofa p mugoya patrick covid 19ug lockdowneffect covid 19",
#  'would consider act spitting people infected corona virus patient tablighijamaat',
#  'indiathanks saluate doctor police supply chain farmer related person fight corona save bharat',
#  '36 new confirmed case china totaling 81,554 place already 859,460 worldwide coronavirus covid 19 china',
#  "hence proved china's bioweapon otherwise wont reopen wet market covid 19",
#  'use big fog machine like italy disinfectant everywhere please coronavirus covid 19',
#  'india press brief community wide spread happening medium tableeghijamaat spreading covid 19',
#  'donald trump use scarf want protect coronavirus prick',
#  'dissent right least uk concerning official coronavirus so-called threat',
#  'covid 19 lockdown situation like existential crisis hanging head .. pmkcallscurfewextension',
#  'cant believe new reality living wh project 100k coronavirus death socialdistancing save life',
#  'last time sick shit im back wit coronavirus',
#  'april fool day im waiting someone say corona shit fake go back normal life',
#  'wanna go pride festival someon e hmu interested obviously corona',
#  'pakistani human bomb difference whether die corona jihad',
#  'demand indian government give minority status coronavirus immediate effect',
#  'yeah corona end world thing get better alright',
#  'swedish state epidemiologist majority covid 19 infection person without symptom',
#  'last hour estimated 141 people tweeted laid coronavirus covid 19',
#  'anxiety roommate since 5th standard fuccking sitting head day 24/7 coronavirus',
#  'top 5 trending hashtags twitter world 1 covid 19 2 coronavirus 3 stayhome 4 covid 19 5 lockdown',
#  'temple donating money mosque spreading corona virus difference hinduism islam',
#  'corona doesnt send tweet tomorrow saying april fool everything go back normal lose',
#  'coronavirus thing reaction many people response mean value worth',
#  'talk economy life sound familiar still thought end corona climate pollution',
#  'trump say 100k death coronavirus win wtf really going',
#  'jaejoong seriously said hospitalized w covid 19 april fool joke fuk seriously funny .. ugh',
#  'duh fact wuhan locked sign enough covid 19 deadly damn serious',
#  'breakingnews coronavirus death toll u reach 4,000 via',
#  'like coronavirus wait thousand dying address global warming itll way late',
#  '1 new recovery uzbekistan totaling 8 place already 178,135 worldwide coronavirus covid 19 uzbekistan',
#  "kim jae joong cancelled y'all joke please corona",
#  'health ministry 112 new case coronavirus past 24 hour total 855 kuna kuwait',
#  'fuck china evil liar commie news coronavirus kungflu cnn msnbc chinesevirus america',
#  'death toll far corona virus 1 police brutality 3',
#  'get yall bored due corona yada yada damn miserable like let people happy',
#  'horrible want corona diverted kafir countries.this hidden mindset rarely exposed video',
#  'likh ke lelo 15 shaban vaccine corona come arrivalofimammahdi',
#  'icymi trump one first moron call coronavirus flu',
#  'hasta covid 19 gikuhaan gihimong covid 14 hmmm well expect',
#  'yall really think corona virus came nowhere .. damn gov trying kill population',
#  'testing kit case duh le casulaties coronavirus thelockdown coronavirustruth',
#  'corona virus scaring virus move fast china 3 week ago',
#  'kind presidential message need usa pandemic covid 19 imwithher',
#  "amidst whole covid 19 pandemic crisis country rolling 5g signing bill's law need focus",
#  'many bill little money :) thanks covid 19 hope get fucked as cactus',
#  'maaan pen flowin knocking alot feature release somn new newmusic quarantine covid 19 hiphop',
#  'american revolution 2 fought musket microscope covid 19 coronavirus stayathome',
#  'yall good mathematician yall scared coronavirus regularly text drive',
#  "covid 19 control ... i'll bet tie pulmonary hypertension",
#  'coronavirus need end quickly im going insane staying inside house',
#  'health c mutahi kagwe expected brief kenyan covid 19 anytime 3.30 pm',
#  'fuck covid 19 b running wonderful thing wanted plan bff bday coming like aggravating',
#  'one day covid 19 mistake evolve make easy detect symptom easier contain',
#  'jesus fucking christ please let coronavirus wipe u face planet',
#  'unt professor always understanding accommodating really appreciate crazy corona time',
#  'breaking u coronavirus death set one-day record 865',
#  'confirmed covid 19 isnt shame global pandemic affected anyone stay safe dont forget wash ur hand',
#  'breaking number people tested positive corona israel 5,591 97 serious condition 21 died far',
#  'growing rate 1000 people dead per end april 30,000 people dead u covid 19 coronavirus',
#  'ibuprofen probably worsen corona virus symptom many corona virus positive take ibuprofen',
#  'breaking southkorea report 101 case new coronavirus total 9,887 death toll rise 3 165',
#  'unless celebrity donating serious money fighting coronavirus dont give f ck theyre',
#  'make coronavirus april fool joke tomorrow please',
#  'happen rail company people using long keep running near empty train covid 19 afterisolation',
#  'essential reading thread good advice u lka srilanka covid 19sl covid 19',
#  'recored 40,000+ death around world covid 19 stayhome',
#  'first person hear say coronavirus ... april fool tmo gonna get punch throat',
#  'trump making medium watch fake reporting covid 19 cnn cut away beast mode trump 2016 back',
#  'seen ig nigga fuck corona bbq ny ppl really dont care whole thing',
#  'twitter made think black people cant get coronavirus dying disproportionate number',
#  'life stranded stockholm corona pass wow ive got get circadian clock board day 25 easterntime',
#  'lost lil part time check corona today im sad imma miss job',
#  'corona april fool joke today please land serious trouble',
#  'well done getting sleeve rolled helping covid 19 crisis',
#  'hoping thing get better next month global crisis coronavirus',
#  'nothing happen ... mood beg terrorist stop spreading coronavirus ...',
#  'visited phoenixmall march 10 17 request talk corona help line get screened',
#  'time fear let love faith hope make u coronavirus',
#  'cardi b coronavirus vid unfunniest jarring thing social rn sorry sorry x',
#  "there's bigger fuck trump usaid ppe glovesandmasks coronavirus covid 19 ventilator",
#  'mass production ventilator help covid 19 coronavirus covid 19 coronavirususa',
#  'heard construction us-mexico border wall proceeds despite coronavirus pandemic',
#  'besides coronavirus say 2020 still good .. swiveling thru b make happen',
#  'mother sends corona virus bullshit im gunna lose',
#  'hope remain first last case corona positive ranchi',
#  '1 new confirmed case zambia totaling 36 place already 856,900 worldwide coronavirus covid 19 zambia',
#  'trump leader major author lot people believing coronavirus flu',
#  'epicentre coronavirus india found nizamuddin markaz appropriate call marghat nizamuddinmarkaz coronavirusoutbreakindia',
#  'feel like got corona entering grocery store weird experience',
#  'rona thing bitch deserve cute lil nickname covid 19 corona virus fuck bitch',
#  'peter navarro told trump coronavirus would kill 500,000 american back january',
#  'deserve thought agreed make coronavirus related april fool joke jaejoongisoverparty',
#  'someone tell corona virus april fool prank china tired happy new month tho',
#  'lot story ppl tipping delivery driver wish motherfvcker would catch coronavirus catch hand',
#  'somehow began due corona virus please continue nationwide ban liquor cigarette forever healthyindia',
#  'father-of-three 50 made full recovery coronavirus dy heart attack day release',
#  'please please please stop talking trump making coronavirus political im sick hatred',
#  "i'm active mean coronavirus feel fine im following government order like everyone else",
#  'dear soccer really miss please come back already :( also dear corona frick u ruining everything',
#  "dranbumani say there's medicine covid 19 that's social distancing nothing else pmkcallscurfewextension",
#  'poor florida prepare gov desantis many coronavirususa desantis',
#  'covid 19 florida continues escalate 5th highest number case added 1,000 today',
#  'new york country would rank 5th corona virus case across world crazy af',
#  'publish daily update corona case mumbai yesterday',
#  'republican wary coronavirus spending trump urge infrastructure plan u rtgnews',
#  'fuck corona able see work art exhibit',
#  'crisis start war ... en wat horen overal de wereld war coronavirus ...',
#  "say anything corona viruse might bring best mankind we're bad people ...",
#  'one biggest fear ruth bader ginsburg get ill coronavirus ... stay 6 foot away',
#  'wouldnt happen mayor joy belmonte job properly fairly covid 19',
#  'flu feel like youre dying coronavirus must literal hell',
#  'corona shit really made plce hell hole like deadass',
#  'sign online class know cant handle right corona',
#  'feasible could create glass could used detect coronavirus virus',
#  'god please help u devil called corona virus',
#  'way effectively stop corona everything shut 30 day change mind',
#  'doctor healthcare professional warrior protected supreme court tell centre covid 19',
#  'delhi doctor working delhi government hospital tested positive covid 19',
#  "let's forget majority imported covid 19 case u",
#  'ive signed petition calling government deliver coronavirus wage subsidy',
#  'coronavirus hotspot uttar pradesh sealed till april 15 covid 19',
#  'anyone make corona virus prank tomorrow absolutely lose respect someone going though wont',
#  'coronavirus 11 test positive coronavirus kashmir tally 136 tested positive today skim srinagar kashmir flash',
#  'fortunate enough lived srilanka tell health medical system fantastic coronavirus',
#  'new york cannnot afford hospital burnt right corona case',
#  'hope wrong think coronavirus shit going last least 6 month',
#  'suck helpful showing trump coronavirus update communist news network',
#  'unfortunate still parsing hour later covid 19 txlege leadershipmatters',
#  'indian required one listens central order coronavirus misconduct plz',
#  'wonder corona virus would issue killed poor many killing well',
#  'never thought grocery store would gross much covid 19',
#  'heart breaking way see prayer family affected covid 19',
#  "let's u gather mandirs today corona ke chakkar mai ashtmi chorde durgaashtami",
#  "corona gud job ngo's r state cm nd special thanks indianprimeminister sir modi ji",
#  'west bengal death toll raise 6 death 2 covid 19 positive patient health official',
#  'gotta remember everything impermanent dharma covid 19 trump trey phish forgetting fee lyric dig man',
#  'show best holding government account thier approach covid 19 gmb covid 19 covid 19uk',
#  'let satanic force flee region silvia patricia familia james 4.7 coronavirus',
#  'stay safe americaand staythefuckhome want come visit guy soon coronavirus covid 19',
#  'corona virus really delaying moving husband ... weve waiting since july miss damn much',
#  'turn big april fool joke corona actually real right ... :(',
#  "let deal idiocy world ... we'll use covid 19 excuse isolate ... together",
#  'almost hat corona beer much coronavirus like lime though',
#  'regret leaving home 16 day self-quarantine ... yo guy need make least 20 day told covid 19',
#  'many coronavirus ... sike april fool joke going said tomorrow',
#  'much corona test done india 18 test per 1 lakh ..',
#  'corona koi khel nehi musibat hai please follow rule avoid corona virus save life',
#  'ever stop think havent even seen worst corona virus',
#  'wanted go new orleans cali birthday corona still',
#  'love jail doesnt time limit since corona virus miss bestfriend',
#  'nobody trinidad 85 case corona still country baii ...',
#  'colleague need change regulation around vaccine covid 19 health law',
#  'really sick tho corona shit many life taken family hurting',
#  'every damn company put coronavirus commercial week fuck every last one',
#  'look upto sky say thanks god ur alive yet think lost life coz corona',
#  'dr fauci said gonna whole lot body bag coming weeks.corona coroner',
#  'god please forgive u make april month corona cure found lockdownwithblacklove',
#  'corona billion ti wo gbo .. cash season',
#  'would trust coronavirus contact app tracking movement uk government newsnight',
#  '10 new death reported l county today 548 new case covid 19',
#  'drive voting okay joe actually lost coronavirus driveinvoting',
#  'prayer go new york city .. even city corona killling lot ppls loved one',
#  'u coronavirus death pas 4,000 news agency afp quoting john hopkins university coronavirusupdate coronaviruspandemic',
#  'breaking turkish military aircraft carrying medical aid departs italy spain country worst hit novel coronavirus europe',
#  'heart wrenching watching christcuomo tonight fuckcotonavirus covid 19 coronaviruspandemicusa',
#  'thank g42 impressive feat coronavirus diagnostics ramped uae',
#  'may april full heavenly surprise make fool u like corona month inshallah happy new month',
#  'madam cc limit ac dibated ragular intarest due corona sutdown ac pnb 14240087000 1225',
#  'corona big fat sick long infecting as bitch cancel motherfucking plan',
#  'need get planning festival got planned br corona shit',
#  'way could believe chriscuomo got infected coronavirus actually dy believe fakenews',
#  "well i'm officially miserable layoff due trump dropping ball coronavirus",
#  'corona religion connected politics let u fight indian',
#  '3 new death confirmed korea totaling 165 place already 42,149 worldwide coronavirus covid 19 s.korea',
#  'soon corona shit im finna go get bbl',
# ...
#  'yes please support friend bts btsartmy army covid 19 2cool4skooloutnow facemask',
#  'looking somegoodnews even good news covid 19 sure follow',
#  'look like coronavirus roughly 10 time fatal flu minimum 100 000 death like 15 people',
#  'fajr time people forget duas remember unfortunate life lost due horrible wave covid 19',
#  'covid 19 another msm enemy people scam wwg 1wga filmyourhospital',
#  'friend class fellow dr mehdi working aku diagnosed corona pray fast recovery',
#  'connecticut bank credit union offer 90 day grace period mortgage coronavirus pandemic',
#  "man today first day april wish coronavirus big april fool's joke",
#  'might better die corona slack day next 6 month',
#  'jaejoong boy dumb fuck .. joking corona virus like tasteless joke mister',
#  'coronavirus greatest test since world war two say un chief',
#  'expect food shortage coronavirus store sell worker fear',
#  'real question ok wear ski mask questionoftheday covid 19',
#  "due covid 19 situation move loan emi next three month's ... loan 2743815 1 please give reply",
#  'miss tyler want look puppy tyler bullshit fuck',
#  'coronavirus pandemic reliance general insurance launch covid 19 protection insurance cover moneycontrol ...',
#  'viruscorona weapon upset people dying coronavirus',
#  'coronavirus outbreak world confirmed -1,426 096 death 81,865 recovered 300,054 active 1,044 177',
#  'bank deduct 5k account say donation fight corona virus nigeria',
#  'youtube set 480p resolution limit android app across india amid coronavirus lockdown',
#  '2,361 people holed nizamuddin markaz every one coronavirus suspect',
#  'logic releasing sex offender much self explanatory coronavirus',
#  'covid 19 global economy meltdown looming result recession corona virus must eradicated minimal',
#  'announces active compound wp1122 reduces coronavirus replication vitro 100',
#  'aint gon lie corona stressing ... cant house like dawg',
#  "wanna lie got coronavirus april fool's joke come y'all grown ...",
#  'test positive coronavirus get well chris',
#  'doctor explains homemade mask might create false sense security covid 19',
#  'united state coronavirus last update 1/4 2020 2:16 et time coronavirus case 188,592 death 4,055 recovered 7,251',
#  'update least 63 italian doctor coronavirus died italian association doctor',
#  'family keep saying coronavirus shut fuck imma end foreal',
#  'watch live trump coronavirus task force explain updated guideline wh briefing',
#  'fed seeing person speech news channel worse corona',
#  "covid 19 highly confirmed case's side chaina stayhomestaysafe fightagainstcovid 19",
#  'thank god unlike covid 19 swamys reach confined noted individual',
#  'heartbreaking netherlands today report 777 new case 234 new death covid 19',
#  'anywhere address 7th st victorville california somewhere want go corona virus testing',
#  'covid 19 jammuandkashmir status update 14 new case today 11 kashmir 3 jammu',
#  'twitter put solitary confinement due coronavirus perhaps thought',
#  'remember vote trump vote covid 19 november 3rd vote virus watch loved one die',
#  'never let anyone get away denying government strategy covid 19 herd immunity',
#  'new month rain lord use rain wash corona away',
#  "colleague sent stupid april fool's message ka case tsa corona bot honestly guy argh",
#  'stay home safely happly enjoy family let break corona staying home',
#  'coronavirus lead revolution normal people play right work together',
#  'girl went h put pic getting tested corona snap um',
#  'leo liked redick throughout series liked shot tie game must replayed rators stayhome covid 19',
#  'life short corona im moving vacationing scandinavia piercing nipple necessarily order though',
#  'hope happing sc hospital covid 19 read thread',
#  'hate fear getting sick ill think corona',
#  'atleast corona free spreading virus left right bottom centre stop trying deflect issue',
#  'aprilfoolsday fool wish someday could come say silly joke covid 19 salockdown stayathome',
#  'im trynna get shit together corona making shit hard asf',
#  'trump 24th feb coronavirus new hoax trump 8th april blame',
#  'coronajihad saheen bagh funded pfi delhi riot simi pfi corona jihad indian jihadi',
#  'anyone dat april fool dis coronavirus season see heaven aprilfoolsday',
#  'little sister contact someone corona virus thats great',
#  'thank hosting primetime show coronavirus always great job',
#  'republican boomer either believe coronavirus democratic hoax completely deathly terrified',
#  'birthday 2 week think corona cured first 24hr stream x',
#  'nepa bill circulated relief food also done way ... stayathome staysafe covid 19 buhari',
#  'swear corona virus cause bird box type shit',
#  'great conversation ahead building community age coronavirus',
#  'fuck corona cause bday month coming im acting june',
#  'really cry bc im gonna get license anytime soon corona yes',
#  'fewer 1 million total test ... lie teeth daily covid 19',
#  'corona made way hammy tomorrow midnight wont able leave home stay safe baby',
#  "breaking u gov't coronavirus task force presser presser end covid 19",
#  'please sue president withholding help state need coronavirus',
#  'kinda fucked parade dead child around die coronavirus',
#  'dr fauci acknowledged impact covid 19 african american here take health coronavirus',
#  'former classmate dr simple tip coronavirus-proof home',
#  'coronavirus u alcohol sale jump 22 per cent lockdown',
#  'anguilla 2 case 0 0 death covid 19 coronavirus anguilla',
#  'mom karantina diri sendiri bc corona something hurt',
#  'look corona stats shanghai beijing low wuhan closeby',
#  'let avoid corona april fool joke today k',
#  'im waiting covid 19 clear joke start flying tomorrow',
#  "today's april 1st fool day corona virus already played cruel joke made u fool",
#  'sir ji sab corona corona save father suffering heart disease corona',
#  'reminiscing bout ... time able go freely worry coronavirus ):',
#  'anyone considering coronavirus-related prank tomorrow consider decide',
#  'awesome please share navajonation nativetwitter covid 19 covid 19 coronavirus',
#  'jeffpulver rt jessemckinley nygovcuomo calling national unity face coronavirus crisis',
#  'people didnt job coronavirus complaining staying home quarantine im confused',
#  '61 new confirmed case croatia totaling 1,343 place already 2,894 893 worldwide coronavirus covid 19 croatia',
#  'real yall plannedemic critical thinking need apply covid 19 sarscov 2',
#  'dont feel good dont know im exhausted working much corona',
#  'berniesanders rt celentra virtual town hall berniesanders cornelwest others 7 regarding coronavirus',
#  'breaking usa coronavirus death 865 past 24hours john hopkins university',
#  'going 24 hour social medium break dont trust yall make dumb coronavirus-related april fool joke',
#  'ok april 1st aka april fool day sooo corona youre reading please say sike like right',
#  'wondering people wearing glove covid 19 crisis think toiletpapercrisis coronavirus covid 19',
#  'wish covid 19 april fool day prank itd really happy april fool day stay safe guy mwaaah',
#  'day 18 quarantine gave haircut turned really great coronavirus',
#  'many fucking corona virus themed april fool prank think dipshit brand try pull',
#  '7 ... definitely entire two week 7 stayhome covid 19',
#  'one coworkers told government cant force u stay home constitution take corona',
#  "aprilfoolsday corona virus end today what's first thing would",
#  'truth best one order get much okay covid 19',
#  'need enact statewide shelter-in-place responsible every single sc citizen coronavirus covid 19',
#  'coronavirus pandemic u yesterday 1,800 people died america please stay home stay alive',
#  'give maulana corona virus shot see allah save',
#  'present time country would emerge new emerging power world map make corona virus vaccine ... indiavscorona',
#  'look like racist coronavirus set strike innocent people',
#  'every damn time cough feel like damn u got coronavirus',
#  'feel like dr birx could supply world scarf coronavirus',
#  'earlier terrorism religion corona religion kitna defend karoge beemar religion ko ..',
#  'interesting case colitis patient confirmed covid 19',
#  'another day another game lack ability breath anxiety coronavirus stay tuned folk',
#  'due corona virus april west coast tour obviously cancelled ive putting tweeting much suck say',
#  'covid 19 doesnt care religion race pay bracket stay home save life',
#  'happy new month guy let fight covid 19 together stay home',
#  'helpful insight importance racialjustice lens philanthropy nonprofit covid _19',
#  'truthful ive saved ton money staying house due corona',
#  'saying 100,000 ppl sure going drop corona usa shit mane ...',
#  'tested positive covid 19 spreading like wild fly god',
#  'please vote bedford u13 hockey team 10p nh covid 19 vote cast',
#  'office accountant general federation abuja fire go coronavirus donation',
#  'must remember statement turn page covid 19 history japan later',
#  'chris cuomo bless heart tell feel horrible coronavirus',
#  'loses everyones watching coronavirus briefing',
#  'workin song quarantine ... finna hit harder corona beat done cough wont let record',
#  'reinfection due new varients short time likely explanation danger covid 19 coronavirus',
#  'many american life could 25th amendment save right invoked 25thamendment covid 19 moroninchief',
#  'kanika kapoor test positive 5th time . ... hurry get rid coronavirus corona relenting',
#  'cant see one lost ___ covid 19 post heart longer take',
#  'mr president lie seriousness coronavirus threat hard say',
#  'next big pennystock breakout .. selling test kit coronavirus',
#  'ball started rolling hold responsibility chineseviruscorona related worldwide mass killing',
#  'world come coronavirus vaccine soon doomed thanks coronajihad',
#  'someone come tell u coronavirus shit best aprilfoolsday would good news tho',
#  'really cant wait corona resolved level irresponsibility everyone outrageous',
#  'hand coronavirus better cancel halloween kid come house joe exotic theyre getting candy',
#  'similarly pakistani covid 19 genome chinese ... expert comment dr kamran azim',
#  'there cruise ship floating around 4 dead people coronavirus nowhere dock',
#  'yall ever sitting think might coronavirus anyways wa bappin',
#  'find hard focus recently hsdgsdfghsfh med damn corona let buy damn med',
#  'correction nightly coronavirus task force trump edited campaign rally',
#  'anybody know corona virus covid 19 spread glass',
#  'fuck corona im tryna see falling reverse concert',
#  "66 people tested positive coronavirus st augustine's hospital durban 48 staff member",
#  'deliberate attempt spread corona delhi markaj event need invistigated',
#  'beginning think corona virus bio weapon .. kit want uk corona virus contaminated',
#  'corona got u fucking bored made leafyishere come back ...',
#  'almost 2000 people died america yesterday coronavirus wtf china bigger liar lucifer fake 3500 reported death',
#  "based research i've seen coronavirus decided could last 3 maybe 4",
#  'like dinald trump mention uk dealing coronavirus important worry country covid 19',
#  'people within u ex-nyc personally know anyone who coronavirus included 4/7 2020',
#  'coronavirus finally put stop silly april 1 prank news story ke newspaper delight publishing',
#  "i'm getting tired covid 19 alot innocent people r dying",
#  'damn thats crazy senior really gon prom able graduate bc coronavirus',
#  'today day spreading april fool day joke coronavirus covid 19',
#  'need plan today give u hope future coronavirus crisis',
#  'close 40,000 people killed coronaviruspandemic across globe covid 19',
#  'plus side got free subscription today ... got going covid 19 quarentinelife',
#  'corona virus test requirement lot thing .. crazy time ahead',
#  'march finally april please fast bring end corona virus',
#  'one covid 19 patient completely recovers discharged morning raising total 18 health ministry srilanka lka',
#  'ill answering viewer question coronavirus stimulus plan w tomorrow 6am',
#  'damn bro friend grandpa died corona sister im genuinely nervous',
#  "usually love watch news i'm damn sick coronavirus shit unbelievable",
#  'hello april supposed favourite month year corona virus ruining',
#  "ap covid 19 58 y'day today 35 stayhomestaysafe",
#  'imagine 1pant garri done enter 1300 corona virus aside disease kill u still day kill self',
#  'really came 2020 fresh mindset corona done fucked honestly',
#  'one thing realised covid _19 lockdown sitting home quote comment',
#  'former pakistan pacer shoaib akhtar proposes indo-pak odi series raise fund fight covid 19 pandemic',
#  'must keep eye open thing corona virus equal complete consent surveillance',
#  'covid 19 got pocket book hurting ... cancelled hulu subscription service got',
#  'life nothing game best reelection expense worst jesus covid 19',
#  '2 ppl caught coronavirus working store im ppl dont give two fuck',
#  'paano ang tamang pag fill ng social amelioration card watch covid 19 wehealasone dswd',
#  'friend drive new baby wow fuck corona torture want squeeze nugget',
#  'sofia omg corona virus killed 41 thousand people whatever holocaust killed',
#  'end world gonna die one time solidarity ... face fate covid 19 killer 100',
#  'safe buy online item covid 19 affected country especially china',
#  'would like thank healthcare worker hard work fight combat corona virus',
#  'bringing bf coronavirus household aint cute pendeja af selfish',
#  'coronavirus u 1048971 million test done 20:00 eastern time 184,770 tested positive 26,660 critical 3746 death',
#  'positive recovery story always great read covid 19 positivetweetskarona',
#  'honestly wish corona virus would magically disappear everyone get better everything back normal like never happened',
#  'ounce prevention worth pound cure covid 19',
#  'covid 19 fucking around keep ass home wash damn hand covid 4mds covid 4nurses',
#  'hello good morning folk happy new month tukubuke kusanitize nice day coronaviruskenya covid 19 lockdown dontrushchallenge',
#  'really take several deep breath reading new york time coronavirus coverage',
#  'count ya day corona .. dont mess bible hot cross bun biblical',
#  'covid _19 14 new case today 11 kashmir 3 jammu toll rise 139',
#  'corona april fool joke please shit serious anything except corona',
#  'please apologize spreading big awful lie whole nation covid 19',
#  'replaces stuff sent china corona virus still dem hoax crazy shit',
#  '2 lead guy desh corona ko haraa chuka hai coronaindia indiafightscorona corona',
#  'completely wrong plan lockdown people die corona die illness sure',
#  'march 2020 person leaving youll never see last word person coronavirus',
#  'let make april fool corona virus staying home',
#  'tdlr sent email saying barber arnt essential fuck corona fuck tdlr',
#  'please sign petition support arizona holding accountable inaction coronavirus',
#  "sir instead relaxing focusing meditation yoga people's thought fixed corona 24 7 right",
#  'move nap sit damn house due corona imma stay home lol',
#  'breaking foxnews alert coronavirus death toll u reach 4,000',
#  "wonder boris contracted covid 19 doesnt answer question uk's approach pandemic boris conspiracy",
#  'one day church shut empty government closed corona virus rapture',
#  'thank everyone front line sacrifice mean much would lose everything covid 19',
#  'let u persistent continue work hard combat covid 19 infectionprevention',
#  "first spread terrorism world they're spreading corona world tablighijamaat coronajihaad",
#  'cant wait open twitter tomorrow see corona virus cured aprilfoolsday',
#  'great job mr president coronavirus task force',
#  'reinfection due new varients short time likely explanation danger covid 19',
#  'one fucking train per hour still want fucking delayed bmt dont know whats going kill first coronavirus tfl',
#  'r people gunna admit capitalism crumble order nation survive covid 19',
#  "fitness central's corona virus email truly lesson communicate customer crisis",
#  'using smoke like substance spray air corona',
#  'everyones getting depressed corona isolation bitch ive depressed way shit aint phased',
#  'jerk alert post screenshot paying money fight covid 19 outbreak justsaying',
#  ...]

# %% [markdown]
# ### 5. Splitting the dataset for training and testing
#
# This increases out-of-sample accuracy of the model

# %%
train_x, test_x, train_y, test_y = train_test_split(processed_x, y, test_size=0.3, random_state=42)

# %% [markdown]
# ### 6. Taking user input i.e. Tweet by actual user and then analysing its sentiment.
#
# Given that user has to provide actual sentiment of the Tweet in order to perform evaluation metrics of the model.

# %%
tweet_input = input("Enter your tweet: ")
test_x.append(" ".join(process_tweet(tweet_input)))

print("What is the actual Sentiment of the Tweet? Is the tweet covid-positive or covid-negative")
print("Input is essential for calculating model accuracy")
sentiment_input = input('Type: 0 for negative, 1 for positive: ')
senti = [0, 1]


test_y = list(test_y)
while int(sentiment_input) not in senti:
    sentiment_input = input('Wrong input. Try again!: ')

test_y.append(int(sentiment_input))

# %% [markdown]
# ### 7. Feature extraction:
# We are extracting two features from tweets.
# 1. length of processed tweet
# 2. polarity score i.e. amount of positivity , negativity in each tweet.
#
# We are storing feature in a 2-D array as it is required by SVC class

# %%
feature = get_polarity_score(train_x)

feature

# %% [markdown]
# #### Typecasting training set variables to numpy array

# %%
train_x = numpy.array(feature)
train_y = numpy.array(train_y)

# %% [markdown]
# ### 8. Model training
#
# Dimension of variable 'feature' has to be 2 and dimension of variable 'y' has to be 1 as required by SVC classifier

# %%
classify = SVC(kernel="linear")
classify.fit(train_x, train_y)

# %% [markdown]
# ### 9. Processing of Test Dataset

# %%
clean_tweets = []

for tweet in test_x:
    clean_tweets.append(" ".join(process_tweet(tweet)))

test_feature = get_polarity_score(clean_tweets)

test_feature

# %% [markdown]
# #### Typecasting testing set variables into numpy array

# %%
test_feature_x = numpy.array(test_feature)
test_y = numpy.array(test_y)

# %% [markdown]
# ### 10. Model Prediction / Testing

# %%
predict = classify.predict(test_feature_x)

print(f'Tweet: {tweet_input}')
print(f'Tokens: {process_tweet(tweet_input)}')

sentiment = predict[-1]
sentiment = 'Positive' if sentiment == 1 else 'Negative'

print(f'Sentiment: {sentiment}')

# %% [markdown]
# ### 11. Evaluation metrics

# %%
print(f"F1 Score = {f1_score(test_y, predict, average='weighted')}")

# %%
print(f"Jaccard Index = {jaccard_score(test_y, predict)}")

# %% [markdown]
# ### 12. Model Plotting

# %%
plt.scatter(test_feature_x[:, 0], test_y, color='r')
plt.scatter(test_feature_x[:, 1], test_y, color='g')
plt.scatter(test_feature_x[:, 2], test_y, color='m')

# some colours in legend are not visible on plot because of overlapping but they are being rendered
plt.legend(['Length of Tweet', 'Positivity Score', 'Negativity Score'], title="Features")
plt.title("Sentiment against feature")

plt.xlabel("Features", size=14)
plt.ylabel("Sentiment", size=14)

plt.show()
